# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # 1. Data Example

# %%
# Eating, exercise habbit and their body shape
df = pd.DataFrame(columns=['calory', 'breakfast', 'lunch', 'dinner', 'exercise', 'body_shape'])

# %%
df.loc[0] = [1200, 1, 0, 0, 2, 'Skinny']
df.loc[1] = [2800, 1, 1, 1, 1, 'Normal']
df.loc[2] = [3500, 2, 2, 1, 0, 'Fat']
df.loc[3] = [1400, 0, 1, 0, 3, 'Skinny']
df.loc[4] = [5000, 2, 2, 2, 0, 'Fat']
df.loc[5] = [1300, 0, 0, 1, 2, 'Skinny']
df.loc[6] = [3000, 1, 0, 1, 1, 'Normal']
df.loc[7] = [4000, 2, 2, 2, 0, 'Fat']
df.loc[8] = [2600, 0, 2, 0, 0, 'Normal']
df.loc[9] = [3000, 1, 2, 1, 1, 'Fat']
df.loc[10] = [3000, 1, 2, 1, 1, 'Fat']

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#    calory  breakfast  lunch  dinner  exercise body_shape
# 0    1200          1      0       0         2     Skinny
# 1    2800          1      1       1         1     Normal
# 2    3500          2      2       1         0        Fat
# 3    1400          0      1       0         3     Skinny
# 4    5000          2      2       2         0        Fat
# 5    1300          0      0       1         2     Skinny
# 6    3000          1      0       1         1     Normal
# 7    4000          2      2       2         0        Fat
# 8    2600          0      2       0         0     Normal
# 9    3000          1      2       1         1        Fat

# %%
df.to_csv('shape.csv')

# %%
df=pd.read_csv('shape.csv')

# %%
df.shape
# Out:
# (10, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  10 non-null     int64
#  1   Unnamed: 0    10 non-null     int64
#  2   calory        10 non-null     int64
#  3   breakfast     10 non-null     int64
#  4   lunch         10 non-null     int64
#  5   dinner        10 non-null     int64
#  6   exercise      10 non-null     int64
#  7   body_shape    10 non-null     object
# dtypes: int64(7), object(1)
# memory usage: 768.0+ bytes

# %%
df.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0  calory  breakfast  lunch  dinner  exercise  \
# 0             0           0    1200          1      0       0         2
# 1             1           1    2800          1      1       1         1
# 2             2           2    3500          2      2       1         0
# 3             3           3    1400          0      1       0         3
# 4             4           4    5000          2      2       2         0
# 5             5           5    1300          0      0       1         2
# 6             6           6    3000          1      0       1         1
# 7             7           7    4000          2      2       2         0
# 8             8           8    2600          0      2       0         0
# 9             9           9    3000          1      2       1         1
#
#   body_shape
# 0     Skinny
# 1     Normal
# 2        Fat
# 3     Skinny
# 4        Fat
# 5     Skinny
# 6     Normal
# 7        Fat
# 8     Normal
# 9        Fat

# %%
df.tail(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0  calory  breakfast  lunch  dinner  exercise  \
# 5             5           5    1300          0      0       1         2
# 6             6           6    3000          1      0       1         1
# 7             7           7    4000          2      2       2         0
# 8             8           8    2600          0      2       0         0
# 9             9           9    3000          1      2       1         1
#
#   body_shape
# 5     Skinny
# 6     Normal
# 7        Fat
# 8     Normal
# 9        Fat

# %% [markdown]
# # 2. Split feature vectors and labels

# %%
# X is feature vectors
X = df[['calory', 'breakfast', 'lunch', 'dinner', 'exercise']]

# %%
X.head(10)
# Out:
#    calory  breakfast  lunch  dinner  exercise
# 0    1200          1      0       0         2
# 1    2800          1      1       1         1
# 2    3500          2      2       1         0
# 3    1400          0      1       0         3
# 4    5000          2      2       2         0
# 5    1300          0      0       1         2
# 6    3000          1      0       1         1
# 7    4000          2      2       2         0
# 8    2600          0      2       0         0
# 9    3000          1      2       1         1

# %%
Y = df[['body_shape']]

# %%
Y.head(10)
# Out:
#   body_shape
# 0     Skinny
# 1     Normal
# 2        Fat
# 3     Skinny
# 4        Fat
# 5     Skinny
# 6     Normal
# 7        Fat
# 8     Normal
# 9        Fat

# %% [markdown]
# # 3. rescaling feature vectors to all have the same scale

# %%
from sklearn.preprocessing import StandardScaler
x_stn = StandardScaler().fit_transform(X)

# %%
x_stn
# Out:
# array([[-1.35205803,  0.        , -1.3764944 , -1.28571429,  1.        ],
#        [ 0.01711466,  0.        , -0.22941573,  0.14285714,  0.        ],
#        [ 0.61612771,  1.29099445,  0.91766294,  0.14285714, -1.        ],
#        [-1.18091145, -1.29099445, -0.22941573, -1.28571429,  2.        ],
#        [ 1.89972711,  1.29099445,  0.91766294,  1.57142857, -1.        ],
#        [-1.26648474, -1.29099445, -1.3764944 ,  0.14285714,  1.        ],
#        [ 0.18826125,  0.        , -1.3764944 ,  0.14285714,  0.        ],
#        [ 1.04399418,  1.29099445,  0.91766294,  1.57142857, -1.        ],
#        [-0.15403193, -1.29099445,  0.91766294, -1.28571429, -1.        ],
#        [ 0.18826125,  0.        ,  0.91766294,  0.14285714,  0.        ]])

# %% [markdown]
# # 4. scikit-learn PCA

# %%
from sklearn import decomposition
pca = decomposition.PCA(n_components=1)
sklearn_pca_x = pca.fit_transform(x_stn)

# %%
sklearn_pca_x
# Out:
# array([[-2.22600943],
#        [-0.0181432 ],
#        [ 1.76296611],
#        [-2.73542407],
#        [ 3.02711544],
#        [-2.14702579],
#        [-0.37142473],
#        [ 2.59239883],
#        [-0.39347815],
#        [ 0.50902498]])

# %%
Y
# Out:
#   body_shape
# 0     Skinny
# 1     Normal
# 2        Fat
# 3     Skinny
# 4        Fat
# 5     Skinny
# 6     Normal
# 7        Fat
# 8     Normal
# 9        Fat

# %%
sklearn_pca_x
sklearn_result = pd.DataFrame(sklearn_pca_x, columns=['PC1'])
sklearn_result['y-axis']=0.0
sklearn_result['label']=Y
sklearn_result
# Out:
#         PC1  y-axis   label
# 0 -2.226009     0.0  Skinny
# 1 -0.018143     0.0  Normal
# 2  1.762966     0.0     Fat
# 3 -2.735424     0.0  Skinny
# 4  3.027115     0.0     Fat
# 5 -2.147026     0.0  Skinny
# 6 -0.371425     0.0  Normal
# 7  2.592399     0.0     Fat
# 8 -0.393478     0.0  Normal
# 9  0.509025     0.0     Fat

# %%
sns.lmplot('PC1', 'y-axis', data=sklearn_result, fit_reg=False,  # x-axis, y-axis, data, no line
            # marker size
           hue="label") # color
# Out:
# C:\Users\SSD Store\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sklearn_result
# Out:
#         PC1  y-axis   label
# 0 -2.226009     0.0  Skinny
# 1 -0.018143     0.0  Normal
# 2  1.762966     0.0     Fat
# 3 -2.735424     0.0  Skinny
# 4  3.027115     0.0     Fat
# 5 -2.147026     0.0  Skinny
# 6 -0.371425     0.0  Normal
# 7  2.592399     0.0     Fat
# 8 -0.393478     0.0  Normal
# 9  0.509025     0.0     Fat
